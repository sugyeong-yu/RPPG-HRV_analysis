# %% [markdown]
# # csv데이터불러오기

# %%
import os
import heartpy as hp
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy import signal
import csv
import math
from hrvanalysis import get_frequency_domain_features

# %%
# 그래프 확인하기
path_rppg="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\new_rppg\\rppg5.csv"
rppg = load_data(path_rppg)

path_cppg_sg="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\new_cppg\\cppg5.csv"
cppg1 = load_data(path_cppg_sg)

path_cppg_nh="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\new_cppg2\\5_20210222163600_wave.csv"
cppg2 = load_data(path_cppg_nh)

plt.subplot(3,1,1)
plt.xlim([60*30,(120*30)+1 ])
plt.plot(rppg)


plt.subplot(3,1,2)
plt.xlim([60*200, (120*200)+1])
plt.plot(cppg1)


plt.subplot(3,1,3)
plt.xlim([60*60, (120*60)+1])
plt.plot(cppg2)
plt.show()

# %%
# csv파일 불러와서 ppg_data로 반환
def load_data(path):
    f = open(path, 'r', encoding='utf-8-sig')
    rdr = csv.reader(f)
    ppg_data=[]
    for line in rdr:
        ppg_data.extend(line)
    f.close()
    return ppg_data

# %% [markdown]
# # 데이터 정규화 0~1

# %%
from sklearn.preprocessing import MinMaxScaler

def normalization(ppg_data):
    ppg_data=np.array(ppg_data)
    # MinMaxScaler객체 생성
    scaler = MinMaxScaler()
    # MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.  
    scaler.fit(ppg_data.reshape(len(ppg_data),1))
    ppg_scaled = scaler.transform(ppg_data.reshape(len(ppg_data),1))
    #print(type(ppg_scaled))
#     plt.plot(ppg_scaled)
#     plt.show()
    return ppg_scaled.reshape(len(ppg_data))

# %% [markdown]
# # peak detection

# %%
# peak 찾는 함수(amplitude)
def detect_peak(hrdata,distance):
    point=scipy.signal.find_peaks(hrdata,distance=distance)
    peak=np.zeros(len(point[0]))
    for i in range(len(point[0])):
        peak[i]=(hrdata[point[0][i]])
# peak = peak 값 (y축값), point[0] = peak의 x위치
    return(peak,point[0])

# %% [markdown]
# # 시간축으로 변환

# %%
# time은 sec
def Totimedomain(ppg_data,sr,peaks_x,peaks_y):
    #data->timedomain
    num=len(ppg_data)
    time=np.linspace(0,num/sr ,num) # start,stop,num
    

    #peak->timedomain
    time_peaks_x=np.zeros_like(peaks_x,dtype=float)
    for i in range (len(peaks_x)):
        time_peaks_x[i]=time[peaks_x[i]]
     
    return time , time_peaks_x

#cppg_peaks,cppg_points= detect_peak(cppg_scaled,100,1)
#ctime,c_ppg_peaks_x=Totimedomain(cppg_scaled,cppg_points,cppg_peaks)

# %% [markdown]
# # 신호전처리

# %% [markdown]
# ## 1. bandpass filtering

# %%
def preprocessing(hrdata,cut_l,cut_h,sr):
    filtered = hp.filter_signal(hrdata, cutoff = cut_l, sample_rate = sr, order = 3, filtertype='lowpass')
    filtered = hp.filter_signal(filtered, cutoff = cut_h, sample_rate = sr, order = 3, filtertype='highpass')
    
    
    print("-----------------after filtering---------------")
    plt.subplot(1,2,1)
    plt.xlim([0, 1000])
    plt.plot(hrdata)

    plt.subplot(1,2,2)
    plt.xlim([0, 1000])
    plt.plot(filtered)
    plt.show()
    
    print("-------------------------------------------------")
    return filtered

# %%
# 필터링 후 정규화 실험해보기.
from hrvanalysis import get_frequency_domain_features
import csv
# cppg불러오기
sr=255
f = open('C:\\Users\\user\\Desktop\\update\\cppg1.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
for line in rdr:
    ppg_data=line
    #print(line)
print(type(ppg_data))

f.close()   

# list를 numpy array로
# ppg_data=np.array(ppg_data,dtype=np.uint64)

ppg_data=np.array(ppg_data)
ppg_data=ppg_data.astype(np.float64)


# 주파수 스펙트럼
f, psd = scipy.signal.periodogram(ppg_data, fs=sr, window='hann')

plt.plot(f, psd, 'k', linewidth=2)    
plt.xlim([0, 4])
plt.show()


# filtering
filtered=preprocessing(ppg_data,2.0,0.75,sr) # rppg는 0.75~2.0  cppg 0.1~0.3


# 신호정규화 0~1사이값
ppg_scaled=normalization(filtered)
print(len(ppg_scaled))

filtered=ppg_scaled

#peak 검출
ppg_peaks,ppg_points= detect_peak(filtered,133) # peak의 y값과 x값 반환 , 100 , 11

#타임도메인 전환
time,ppg_peaks_x=Totimedomain(filtered,ppg_points,ppg_peaks) # 정규화데이터, 피크x, 피크y ( 그래프그려줌)

# hrv 분석
ppg_hrv=cal_hrv(ppg_peaks,ppg_peaks_x) # 5. hrv계산
ppg_frequency_features = get_frequency_domain_features(ppg_hrv)
print("ppg_hrv_analysis:",ppg_frequency_features)

# 파일로 저장
ppg_frequency_features['num']="12"
print(ppg_frequency_features.values())
f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\rppg_bandfass.csv','a', newline='')
#fieldnames=cppg_frequency_features.keys()
# print(fieldnames)
wr = csv.writer(f)

#wr.writerow(ppg_frequency_features.keys()) 
wr.writerow(ppg_frequency_features.values()) 
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-78d7a330fedc> in <module>
#       4 # cppg불러오기
#       5 sr=255
# ----> 6 f = open('C:\\Users\\user\\Desktop\\update\\cppg1.csv', 'r', encoding='utf-8')
#       7 rdr = csv.reader(f)
#       8 for line in rdr:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\user\\Desktop\\update\\cppg1.csv'

# %% [markdown]
# ## 2. FIR필터사용

# %%
def FIR_filter(data,sr, taps, cutoff, pass_zero):
    x = [0 for _ in range(taps)]
    f_data = []
    
    # 필터 계수
    h = signal.firwin(taps, cutoff=cutoff, pass_zero=pass_zero,fs=sr)  
    for n in range(len(data)):
        for k in range(taps-1, 0, -1):
            x[k] = x[k-1]

        new_input =  int(data[n])
        x[0] = new_input

        out_value = 0

        for k in range(taps):
            out_value = out_value + (h[k] * x[k])

        f_data.insert(n, out_value)
    return f_data

# %% [markdown]
# # R-R Interval 구하기

# %%
# print(cppg_points.shape)
# print(rppg_points.shape)
def length(x1,x2):
    return x2-x1

def cal_ppi(peak_x):
    ppi=np.zeros(len(peak_x)-1)
    print("ppi_shape:", ppi.shape)
    for i in range (len(peak_x)-1):
        peak_dist= length(peak_x[i],peak_x[i+1]) #x축사이의 거리만 (시간차 를 보는 것)
        ppi[i]=peak_dist
    #print(hrv)
    return ppi

# %% [markdown]
# # Data processing

# %%
def Data_processing(c,path,sr):
    ppg_path=path
    ppg_list=os.listdir(ppg_path)    
    print("file_list : ",ppg_list)
    
    for i in range (len(ppg_list)):
        # path 설정
        ppg_path_=ppg_path+'\\'+ppg_list[i]

        # ppg
        print(" file name : ", ppg_list[i])
        print(ppg_path_)
        
        ppg_data=load_data(ppg_path_)
        ppg_data=np.array(ppg_data)
        print("before: ",len(ppg_data))
#         if(len(ppg_data)< (630*sr)) : # 만약 데이터가 10분30초보다 적다면
#             cut_ppg=ppg_data[-18000:] # 뒤에서부터 18000개 가져오기
#         else:    
        cut_ppg=ppg_data[sr*30:sr*660] # 앞에 30초 부터 10분 자르기, 12000~132001 > 120001개 데이터    900~19801 > 18000개데이터
        print("after: ",len(cut_ppg))
        # 5분크기로 30초씩 sift해서 데이터 늘리기
        t1=0
        t2=sr*300 # 5분 -> 300초
#         for j in range(len(cut_ppg)):
#             new_ppg=ppg_data[t1:t2]
#             f = open('E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\cut_'+c+'\\'+str(ppg_list[i][:5])+'_'+str(j)+'.csv','w', newline='')
#             wr = csv.writer(f)
#             wr.writerow(new_ppg) 
#             f.close()
#             t1 = t1+(30*sr)
#             t2 = t2+(30*sr)
#             if t2>len(cut_ppg) :
#                 break;
#             print('slicing ppg 저장: ', str(i)+'_'+str(j))
            
            
#path=E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\new_cppg
path="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\new_rppg"
Data_processing("rppg",path,30)
# Out:
# file_list :  ['rppg4.csv', 'rppg1.csv', 'rppg2.csv', 'rppg3.csv', 'rppg7.csv', 'rppg8.csv', 'rppg9.csv', 'rppg10.csv', 'rppg11.csv', 'rppg12.csv', 'rppg13.csv', 'rppg14.csv', 'rppg15.csv', 'rppg16.csv', 'rppg17.csv', 'rppg5.csv', 'rppg6.csv']
#  file name :  rppg4.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg4.csv
# before:  19726
# after:  18826
#  file name :  rppg1.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg1.csv
# before:  19817
# after:  18900
#  file name :  rppg2.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg2.csv
# before:  19867
# after:  18900
#  file name :  rppg3.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg3.csv
# before:  19886
# after:  18900
#  file name :  rppg7.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg7.csv
# before:  19734
# after:  18834
#  file name :  rppg8.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg8.csv
# before:  19656
# after:  18756
#  file name :  rppg9.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg9.csv
# before:  19253
# after:  18353
#  file name :  rppg10.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg10.csv
# before:  18773
# after:  17873
#  file name :  rppg11.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg11.csv
# before:  19394
# after:  18494
#  file name :  rppg12.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg12.csv
# before:  19205
# after:  18305
#  file name :  rppg13.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg13.csv
# before:  19787
# after:  18887
#  file name :  rppg14.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg14.csv
# before:  19202
# after:  18302
#  file name :  rppg15.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg15.csv
# before:  19420
# after:  18520
#  file name :  rppg16.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg16.csv
# before:  19573
# after:  18673
#  file name :  rppg17.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg17.csv
# before:  19464
# after:  18564
#  file name :  rppg5.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg5.csv
# before:  19754
# after:  18854
#  file name :  rppg6.csv
# E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg6.csv
# before:  19652
# after:  18752

# %% [markdown]
# # 개별실행

# %%
i=0
j=0 # 0~9
sr=200
c_distance=12
# path 설정
cppg_path="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\cut_cppg\\cppg"+str(i)+".csv"

rppg_path="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\new_rppg\\rppg"+str(i)+".csv"

#cppg
print(" cppg file name : ", cppg_path)
ppg_data=load_data(cppg_path)
#print(ppg_data)
ppg_data=np.array(ppg_data) # list를 numpy array로
cut_ppg=cut_data(ppg_data,sr)
ppg_data=cut_ppg.astype(np.float64)


# plt.plot(ppg_data)
# plt.xlim([0, 3000])
# plt.show()

# # # 주파수스펙트럼 시각화.
# # f, psd = scipy.signal.periodogram(ppg_data, fs=sr, window='hann')

# # plt.plot(f, psd, 'k', linewidth=2)    
# # plt.xlim([0, 4])
# # plt.show()

# filtered= preprocessing(ppg_data,2.0,0.5,sr) #FIR_filter(ppg_data,200,40,0.032,True)

# ppg_scaled=normalization(filtered)
# plt.plot(ppg_scaled)
# plt.xlim([0, 3000])
# plt.show()

# peaks_y,peaks_x= detect_peak(ppg_scaled,c_distance)
# print("-------------------timedomain-------------------")
# time,time_peaks_x=Totimedomain(ppg_scaled,sr,peaks_x,peaks_y)

# print(time[-1])

# # 시각화 (peak와 wave)
# plt.scatter(time_peaks_x, peaks_y)
# plt.plot(time,ppg_scaled)
# plt.xlim([580, 590])
# plt.xlabel('time')
# plt.ylabel('signal')
# plt.show()
# print("------------------------------------------------")


# cppg_ppi=cal_ppi(time_peaks_x)



# # rppg
# print(" rppg file name : ", rppg_path)

# sr=30
# r_distance=15

# ppg_data=load_data(rppg_path)
# #print(ppg_data)
# ppg_data=np.array(ppg_data) # list를 numpy array로
# cut_ppg=cut_data(ppg_data,30)
# ppg_data=cut_ppg.astype(np.float64)


# plt.plot(ppg_data)
# plt.xlim([0, 300])
# plt.show()

# ppg_scaled=normalization(ppg_data)
# plt.plot(ppg_scaled)
# plt.xlim([0, 300])
# plt.show()

# peaks_y,peaks_x= detect_peak(ppg_scaled,r_distance)
# print("-------------------timedomain-------------------")
# time,time_peaks_x=Totimedomain(ppg_scaled,sr,peaks_x,peaks_y)

# print(time[-1])


# # 시각화 (peak와 wave)
# plt.scatter(time_peaks_x, peaks_y)
# plt.plot(time,ppg_scaled)
# plt.xlim([40, 50])
# plt.xlabel('time')
# plt.ylabel('signal')
# plt.show()
# print("------------------------------------------------")
# rppg_ppi=cal_ppi(time_peaks_x)





# # ppi 비교
# # ppi 시각화
# if len(cppg_ppi)>len(rppg_ppi):
#     cppg_ppi=cppg_ppi[:len(rppg_ppi)]
# elif len(cppg_ppi)<len(rppg_ppi):
#     rppg_ppi=rppg_ppi[:len(cppg_ppi)]
# plt.scatter(rppg_ppi,cppg_ppi)
# plt.plot([0.25,1.5],[0.25,1.5],color='red',linestyle='--')
# plt.show()



# # hrv분석
# cppg_frequency_features = get_frequency_domain_features(cppg_ppi)
# rppg_frequency_features = get_frequency_domain_features(rppg_ppi)

# #  csv로 결과 저장
# # 1. cppg
# cppg_frequency_features['num']= i
# rppg_frequency_features['num']= i
# f = open('E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\hrv_features\\new_cppgprocess\\'+str(i)+'.csv','w', newline='')
# wr = csv.writer(f)
# wr.writerow(cppg_frequency_features.keys()) 
# wr.writerow(cppg_frequency_features.values())
# wr.writerow(rppg_frequency_features.values()) 
# f.close()
# Out:
#  cppg file name :  E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_cppg\cppg4.csv
# -----------------after filtering---------------
# -------------------------------------------------
# <class 'numpy.ndarray'>
# -------------------timedomain-------------------
# 600.005
# ------------------------------------------------
# ppi_shape: (802,)
#  rppg file name :  E:\prlab\ysg\rppg\rppg_HRV\data\ppg_signal\new_rppg\rppg4.csv
# <class 'numpy.ndarray'>
# -------------------timedomain-------------------
# 597.5333333333333
# ------------------------------------------------
# ppi_shape: (798,)
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 5, using nperseg = 5
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %% [markdown]
# # main

# %%
# rppg code
def ppg_ppi_analysis(path,sr,processing,distance):
    # 1. load data
    ppg_data=load_data(path)
    ppg_data=np.array(ppg_data) # list를 numpy array로
    ppg_data=ppg_data.astype(np.float64)
    
    if processing ==True :
        #filtered=preprocessing(ppg_data,2.0,0.75,sr)
        filtered=FIR_filter(ppg_data,50,0.032,True)
    else :
        filtered=preprocessing(ppg_data,2.0,0.75,sr)
    
    # 2. 신호정규화 0~1사이값
    ppg_scaled=normalization(filtered)

    # 3. peak 검출
    peaks_y,peaks_x= detect_peak(ppg_scaled,distance) # peak의 y값과 x값 반환.

    # 4, 타임도메인 전환
    time,time_peaks_x=Totimedomain(ppg_scaled,sr,peaks_x,peaks_y) # 정규화데이터, 피크x, 피크y ( 그래프그려줌)
    
    # 5. ppi 계산
    ppg_ppi=cal_ppi(time_peaks_x)
    
    # ppg x, y 데이터 반환
    return ppg_ppi

# %%
def main() :
    cppg_path="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\cut_cppg"
    cppg_list=os.listdir(cppg_path)    
    print(" cppg_file_list : ",cppg_list)
        
    rppg_path="E:\\prlab\\ysg\\rppg\\rppg_HRV\\data\\ppg_signal\\cut_rppg"
    rppg_list=os.listdir(rppg_path)
    print(" rppg_file_list : ",rppg_list)
    
    for i in range (len(cppg_list)):
        # path 설정
        rppg_path_=rppg_path+'\\'+rppg_list[i]
        cppg_path_=cppg_path+'\\'+cppg_list[i]
        
#         #cppg
#         print(" file name : ", cppg_list[i])
#         cppg_ppi=ppg_ppi_analysis(cppg_path_, 255, True, 133)
        
        
#         #rppg
#         print( " file name : ", rppg_list[i])
#         rppg_ppi=ppg_ppi_analysis(rppg_path_, 30, False, 12)
        
        
#         # ppi 시각화
#         if len(cppg_ppi)>len(rppg_ppi):
#             cppg_ppi=cppg_ppi[:len(rppg_ppi)]
#         elif len(cppg_ppi)<len(rppg_ppi):
#             rppg_ppi=rppg_ppi[:len(cppg_ppi)]
#         plt.scatter(rppg_ppi,cppg_ppi)
#         plt.plot([0.25,1.5],[0.25,1.5],color='red',linestyle='--')
#         plt.show()
        
#         # hrv분석
#         cppg_frequency_features = get_frequency_domain_features(cppg_ppi)
#         rppg_frequency_features = get_frequency_domain_features(rppg_ppi)
        
#         #  csv로 결과 저장
#         # 1. cppg
#         cppg_frequency_features['num']= i
#         f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\cppg.csv','w', newline='')
#         wr = csv.writer(f)
#         if i==1:
#             wr.writerow(cppg_frequency_features.keys()) 
#         wr.writerow(cppg_frequency_features.values()) 
#         f.close()
        
#         # 2. rppg
#         rppg_frequency_features['num']= i
#         f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\cppg.csv','w', newline='')
#         wr = csv.writer(f)
#         if i==1:
#             wr.writerow(rppg_frequency_features.keys()) 
#         wr.writerow(rppg_frequency_features.values()) 
#         f.close()

# %%
main() # 지금은 c는 fir, r은 band 쓴것.
# Out:
#  cppg_file_list :  ['cppg4_0.csv', 'cppg4_1.csv', 'cppg4_2.csv', 'cppg4_3.csv', 'cppg4_4.csv', 'cppg4_5.csv', 'cppg4_6.csv', 'cppg4_7.csv', 'cppg4_8.csv', 'cppg4_9.csv', 'cppg4_10.csv', 'cppg1_0.csv', 'cppg1_1.csv', 'cppg1_2.csv', 'cppg1_3.csv', 'cppg1_4.csv', 'cppg1_5.csv', 'cppg1_6.csv', 'cppg1_7.csv', 'cppg1_8.csv', 'cppg1_9.csv', 'cppg1_10.csv', 'cppg3_0.csv', 'cppg3_1.csv', 'cppg3_2.csv', 'cppg3_3.csv', 'cppg3_4.csv', 'cppg3_5.csv', 'cppg3_6.csv', 'cppg3_7.csv', 'cppg3_8.csv', 'cppg3_9.csv', 'cppg3_10.csv', 'cppg2_0.csv', 'cppg2_1.csv', 'cppg2_2.csv', 'cppg2_3.csv', 'cppg2_4.csv', 'cppg2_5.csv', 'cppg2_6.csv', 'cppg2_7.csv', 'cppg2_8.csv', 'cppg2_9.csv', 'cppg2_10.csv']
#  rppg_file_list :  ['rppg4_0.csv', 'rppg4_1.csv', 'rppg4_2.csv', 'rppg4_3.csv', 'rppg4_4.csv', 'rppg4_5.csv', 'rppg4_6.csv', 'rppg4_7.csv', 'rppg4_8.csv', 'rppg4_9.csv', 'rppg1_0.csv', 'rppg1_1.csv', 'rppg1_2.csv', 'rppg1_3.csv', 'rppg1_4.csv', 'rppg1_5.csv', 'rppg1_6.csv', 'rppg1_7.csv', 'rppg1_8.csv', 'rppg1_9.csv', 'rppg1_10.csv', 'rppg2_0.csv', 'rppg2_1.csv', 'rppg2_2.csv', 'rppg2_3.csv', 'rppg2_4.csv', 'rppg2_5.csv', 'rppg2_6.csv', 'rppg2_7.csv', 'rppg2_8.csv', 'rppg2_9.csv', 'rppg2_10.csv', 'rppg3_0.csv', 'rppg3_1.csv', 'rppg3_2.csv', 'rppg3_3.csv', 'rppg3_4.csv', 'rppg3_5.csv', 'rppg3_6.csv', 'rppg3_7.csv', 'rppg3_8.csv', 'rppg3_9.csv', 'rppg3_10.csv']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-84923ae22953> in <module>
# ----> 1 main() # 지금은 c는 fir, r은 band 쓴것.
#
# <ipython-input-22-ca85a112b72b> in main()
#      10     for i in range (len(cppg_list)):
#      11         # path 설정
# ---> 12         rppg_path_=rppg_path+'\\'+rppg_list[i]
#      13         cppg_path_=cppg_path+'\\'+cppg_list[i]
#      14
#
# IndexError: list index out of range
