# %% [markdown]
# # csv데이터불러오기

# %%
import os
import heartpy as hp
import matplotlib.pyplot as plt
import numpy as np
import scipy
import csv
import math

# %%
# csv파일 불러와서 ppg_data로 반환
def load_data(path):
    f = open(path, 'r', encoding='utf-8')
    rdr = csv.reader(f)
    for line in rdr:
        ppg_data=line
    f.close()
    return ppg_data

# %% [markdown]
# # 데이터 정규화 0~1

# %%
from sklearn.preprocessing import MinMaxScaler

def normalization(ppg_data):
    ppg_data=np.array(ppg_data)
    # MinMaxScaler객체 생성
    scaler = MinMaxScaler()
    # MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.  
    scaler.fit(ppg_data.reshape(len(ppg_data),1))
    ppg_scaled = scaler.transform(ppg_data.reshape(len(ppg_data),1))
    print(type(ppg_scaled))
#     plt.plot(ppg_scaled)
#     plt.show()
    return ppg_scaled.reshape(len(ppg_data))

# %% [markdown]
# # peak detection

# %%
# peak 찾는 함수(amplitude)
def detect_peak(hrdata,distance):
    point=scipy.signal.find_peaks(hrdata,distance=distance)
#     print(point[0])
# point[0]가 peak의 x좌표 hrdata[point[0]]이 peak의 y좌표
#     plt.subplot(5,2,i+1)
#     plt.scatter(point[0],hrdata[point[0]])
#     plt.plot(hrdata)
#     plt.axis([500, 2000,0,1])
    peak=np.zeros(len(point[0]))
    for i in range(len(point[0])):
        peak[i]=(hrdata[point[0][i]])
#     print(peak)
# peak = peak 값 (y축값), point[0] = peak의 x위치
    return(peak,point[0])
# detect_peak(hrdata)

# %% [markdown]
# # 시간축으로 변환

# %%
# time은 sec
def Totimedomain(ppg_data,peaks_x,peaks_y):
    #data->timedomain
    # 1. 데이터 수만큼의 배열선언 2. 데이터로 시간을 넣어주기 ( 360초 / data수 )*(index+1)   # c 의 sr은 225, r 의 sr은 30 
    
    num=len(ppg_data)
    time=np.linspace(0,num/sr ,num) # start,stop,num
    
#     time=np.zeros_like(ppg_data,dtype=float)
#     for i in range (len(time)):
#         time[i]=round((360/num)*(i+1),4)
    
    #peak->timedomain
    #1.peak y 축 데이터 보존 , peak x 는 데이터 인덱스,,니까 peak_x=360/data수 * (index+1)
    ppg_peaks_x=np.zeros_like(peaks_x,dtype=float)
    for i in range (len(peaks_x)):
        ppg_peaks_x[i]=time[peaks_x[i]]
    
    print("time:", time.shape)
    
    plt.scatter(ppg_peaks_x, peaks_y)
    plt.plot(time,ppg_data)
    plt.xlim([0, 10])
    plt.xlabel('time')
    plt.ylabel('signal')
    plt.show()
    
    return time , ppg_peaks_x

#cppg_peaks,cppg_points= detect_peak(cppg_scaled,100,1)
#ctime,c_ppg_peaks_x=Totimedomain(cppg_scaled,cppg_points,cppg_peaks)

# %% [markdown]
# # 신호전처리

# %% [markdown]
# ## 1. bandpass filtering

# %%
def preprocessing(hrdata,cut_l,cut_h,sr):
    filtered = hp.filter_signal(hrdata, cutoff = cut_l, sample_rate = sr, order = 3, filtertype='lowpass')
    filtered = hp.filter_signal(filtered, cutoff = cut_h, sample_rate = sr, order = 3, filtertype='highpass')
    
    plt.subplot(1,2,1)
    plt.xlim([0, 200])
    plt.plot(hrdata)

    plt.subplot(1,2,2)
    plt.xlim([0, 200])
    plt.plot(filtered)
    plt.show()
    
    return filtered

# %%
# 필터링 후 정규화 실험해보기.
from hrvanalysis import get_frequency_domain_features
import csv
# cppg불러오기
sr=30
f = open('D:\\prlab\\ysg\\HRV\\data\\ppg_signal\\rppg\\rppg12.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
for line in rdr:
    ppg_data=line
    #print(line)
print(type(ppg_data))

f.close()   

# list를 numpy array로
# ppg_data=np.array(ppg_data,dtype=np.uint64)

ppg_data=np.array(ppg_data)
ppg_data=ppg_data.astype(np.float64)


# 주파수 스펙트럼
f, psd = scipy.signal.periodogram(ppg_data, fs=sr, window='hann')

plt.plot(f, psd, 'k', linewidth=2)    
plt.xlim([0, 4])
plt.show()


# filtering
filtered=preprocessing(ppg_data,2.0,0.75,sr) # rppg는 0.75~2.0  cppg 0.1~0.3


# 신호정규화 0~1사이값
ppg_scaled=normalization(filtered)
print(len(ppg_scaled))

filtered=ppg_scaled

#peak 검출
ppg_peaks,ppg_points= detect_peak(filtered,12) # peak의 y값과 x값 반환 , 100 , 11

#타임도메인 전환
time,ppg_peaks_x=Totimedomain(filtered,ppg_points,ppg_peaks) # 정규화데이터, 피크x, 피크y ( 그래프그려줌)

# hrv 분석
ppg_hrv=cal_hrv(ppg_peaks,ppg_peaks_x) # 5. hrv계산
ppg_frequency_features = get_frequency_domain_features(ppg_hrv)
print("ppg_hrv_analysis:",ppg_frequency_features)

# 파일로 저장
ppg_frequency_features['num']="12"
print(ppg_frequency_features.values())
f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\rppg_bandfass.csv','a', newline='')
#fieldnames=cppg_frequency_features.keys()
# print(fieldnames)
wr = csv.writer(f)

#wr.writerow(ppg_frequency_features.keys()) 
wr.writerow(ppg_frequency_features.values()) 
f.close()
# Out:
# <class 'list'>

# %% [markdown]
# ## 2. scipy bandpass filter

# %%
from scipy import signal


def fir_filter(data, lowcut, highcut, fs, order=21):
    nyq = 0.5 * fs # sr의 절반
    low = lowcut / nyq
    high = highcut / nyq
    if low == 0 and high == 1:
        return data
    elif low == 0 and high != 1:
        coeff = signal.firwin(order, highcut / nyq) ## 필터를 만드는거임
    elif low != 0 and high == 1:
        coeff = signal.firwin(order, lowcut / nyq, pass_zero=False)
    elif low != 0 and high != 1:
        coeff = signal.firwin(order, [low, high], pass_zero=False)
    output = signal.lfilter(coeff, 1.0, data)## 필터를 적용
    
    plt.subplot(1,2,1)
    plt.xlim([0, 2000])
    plt.plot(data)

    plt.subplot(1,2,2)
    plt.xlim([0, 2000])
    plt.plot(output)
    plt.show()
    
    return output

# %%
# 필터링 후 정규화 실험해보기.
from hrvanalysis import get_frequency_domain_features
import csv
# cppg불러오기
sr=255
f = open('D:\\prlab\\ysg\\HRV\\data\\ppg_signal\\cppg\\cppg12.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
for line in rdr:
    ppg_data=line
    #print(line)
print(type(ppg_data))

f.close()   

# list를 numpy array로
#ppg_data=np.array(ppg_data,dtype=np.uint64)

ppg_data=np.array(ppg_data)
ppg_data=ppg_data.astype(np.float64)


# 주파수 스펙트럼
f, psd = scipy.signal.periodogram(ppg_data, fs=sr, window='hann')

plt.plot(f, psd, 'k', linewidth=2)    
plt.xlim([0, 4])
plt.show()

# filtering
filtered=fir_filter(ppg_data,0.75,2.0,sr) # rppg는 0.75~2.0  cppg 0.75~0.2

f, psd = scipy.signal.periodogram(filtered, fs=sr, window='hann')

plt.plot(f, psd, 'k', linewidth=2)    
plt.xlim([0, 4])
plt.show()



# 신호정규화 0~1사이값
ppg_scaled=normalization(filtered)
print(len(ppg_scaled))

filtered=ppg_scaled

#peak 검출
ppg_peaks,ppg_points= detect_peak(filtered,133) # peak의 y값과 x값 반환 , 100 , 11

#타임도메인 전환
time,ppg_peaks_x=Totimedomain(filtered,ppg_points,ppg_peaks) # 정규화데이터, 피크x, 피크y ( 그래프그려줌)

# hrv 분석
ppg_hrv=cal_hrv(ppg_peaks,ppg_peaks_x) # 5. hrv계산
ppg_frequency_features = get_frequency_domain_features(ppg_hrv)
print("ppg_hrv_analysis:",ppg_frequency_features)


# 파일로 저장
ppg_frequency_features['num']="12"
print(ppg_frequency_features.values())
f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\cppg_scipy.csv','a', newline='')
#fieldnames=cppg_frequency_features.keys()
# print(fieldnames)
wr = csv.writer(f)
#wr.writerow(ppg_frequency_features.keys()) 
wr.writerow(ppg_frequency_features.values()) 
f.close()
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# 91778
# time: (91778,)
# hrv_shape: (450,)
# ppg_hrv_analysis: {'lf': 3.007864731116434e-05, 'hf': 6.921501219590659e-05, 'lf_hf_ratio': 0.4345682584874731, 'lfnu': 30.29261632664709, 'hfnu': 69.70738367335291, 'total_power': 0.00010932929633187405, 'vlf': 1.0035636824803112e-05}
# dict_values([3.007864731116434e-05, 6.921501219590659e-05, 0.4345682584874731, 30.29261632664709, 69.70738367335291, 0.00010932929633187405, 1.0035636824803112e-05, '12'])
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %% [markdown]
# # R-R Interval 구하기

# %%
# print(cppg_points.shape)
# print(rppg_points.shape)
def length(x1,y1,x2,y2):
    return math.sqrt(math.pow(x2-x1,2)+math.pow(y2-y1,2))

def cal_hrv(peak_y,peak_x):
    hrv=np.zeros(len(peak_x)-1)
    print("hrv_shape:", hrv.shape)
    for i in range (len(peak_x)-1):
        peak_dist= length(peak_x[i],peak_y[i],peak_x[i+1],peak_y[i+1])
#         print(peak_dist)
        hrv[i]=peak_dist
    #print(hrv)
    return hrv

# %% [markdown]
# # 개별실행

# %%
# 파일 하나씩 돌리기
from hrvanalysis import get_frequency_domain_features
import csv
# cppg불러오기
sr=255
f = open('D:\\prlab\\ysg\\HRV\\data\\ppg_signal\\cppg\\cppg8.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
for line in rdr:
    ppg_data=line
    #print(line)
print(type(ppg_data))
f.close()   

# list를 numpy array로
ppg_data=np.array(ppg_data)
#rppg_data=np.array(rppg_data)
# 신호정규화 0~1사이값
ppg_scaled=normalization(ppg_data)
print(len(ppg_scaled))

# 주파수 스펙트럼
f, psd = scipy.signal.periodogram(ppg_scaled, fs=sr, window='hann')

plt.plot(f, psd, 'k', linewidth=2)    
plt.xlim([0, 4])
plt.show()

# filtering
filtered=preprocessing(ppg_scaled,2.0,0.75,sr) # rppg는 0.75~2.0  cppg 0.1~0.3


#peak 검출
ppg_peaks,ppg_points= detect_peak(filtered,135) # peak의 y값과 x값 반환 , 100 , 11

#타임도메인 전환
time,ppg_peaks_x=Totimedomain(filtered,ppg_points,ppg_peaks) # 정규화데이터, 피크x, 피크y ( 그래프그려줌)

# hrv 분석
ppg_hrv=cal_hrv(ppg_peaks,ppg_peaks_x) # 5. hrv계산
ppg_frequency_features = get_frequency_domain_features(ppg_hrv)
print("ppg_hrv_analysis:",ppg_frequency_features)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# 91779
# time: (91779,)
# hrv_shape: (441,)
# ppg_hrv_analysis: {'lf': 3.7339335077821215e-06, 'hf': 1.1695240634294694e-05, 'lf_hf_ratio': 0.3192694895762018, 'lfnu': 24.200475497903238, 'hfnu': 75.79952450209677, 'total_power': 1.661545741454718e-05, 'vlf': 1.1862832724703647e-06}
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %%
# 파일 하나씩 돌리기
from hrvanalysis import get_frequency_domain_features
import csv
# cppg불러오기
sr=30
f = open('D:\\prlab\\ysg\\HRV\\data\\ppg_signal\\rppg\\rppg5.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
for line in rdr:
    ppg_data=line
    #print(line)
print(type(ppg_data))
f.close()   

# list를 numpy array로
ppg_data=np.array(ppg_data)
#ppg_data=ppg_data.astype(np.float64)
#rppg_data=np.array(rppg_data)
# 신호정규화 0~1사이값
ppg_scaled=normalization(ppg_data)
print(type(ppg_scaled))

# 주파수 스펙트럼
f, psd = scipy.signal.periodogram(ppg_scaled, fs=sr, window='hann')

plt.plot(f, psd, 'k', linewidth=2)    
plt.xlim([0, 4])
plt.show()

# filtering
filtered=preprocessing(ppg_scaled,2.0,0.75,sr) # rppg는 0.75~2.0  cppg 0.1~0.3


#peak 검출
ppg_peaks,ppg_points= detect_peak(filtered,11) # peak의 y값과 x값 반환 , 100 , 11

#타임도메인 전환
time,ppg_peaks_x=Totimedomain(filtered,ppg_points,ppg_peaks) # 정규화데이터, 피크x, 피크y ( 그래프그려줌)

# hrv 분석
ppg_hrv=cal_hrv(ppg_peaks,ppg_peaks_x) # 5. hrv계산
ppg_frequency_features = get_frequency_domain_features(ppg_hrv)
print("ppg_hrv_analysis:",ppg_frequency_features)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# time: (10775,)
# hrv_shape: (422,)
# ppg_hrv_analysis: {'lf': 9.959904287895518e-05, 'hf': 0.00023740498097954993, 'lf_hf_ratio': 0.4195322375630132, 'lfnu': 29.55425924551362, 'hfnu': 70.44574075448638, 'total_power': 0.00037007731004890166, 'vlf': 3.3073286190396556e-05}
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %% [markdown]
# # 메인함수 실행

# %%
# 파일 한번에 돌리기.
import os
from hrvanalysis import get_frequency_domain_features

def hrv_frequency(c_or_r,distance):
    # c_or_r : cppg이거나 rppg이거나, 0이면 cppg, 그렇지 않으면 rppg
    if c_or_r ==0:
        sr=255
        cut_l=2.0
        cut_h=0.75
        filepath="D:\\prlab\\ysg\\HRV\\data\\ppg_signal\\cppg"
        filelist=os.listdir(filepath)
        print(filelist)

    else :
        sr=30
        cut_l=2.0
        cut_h=0.75
        filepath="D:\\prlab\\ysg\\HRV\\data\\ppg_signal\\rppg"
        filelist=os.listdir(filepath)
        print(filelist)

            
            
    for i in range (len(filelist)):
        print("file_name",filelist[i])
        path=filepath+'\\'+filelist[i]
        ppg_data=load_data(path) # 1. ppg data 하나씩 load
        ppg_scaled=normalization(ppg_data) # 2. 정규화 0~1
        filtered=ppg_scaled
#         # 주파수 스펙트럼
#         f, psd = scipy.signal.periodogram(ppg_scaled, fs=sr, window='hann')

#         plt.plot(f, psd, 'k', linewidth=2)    
#         plt.xlim([0, 4])
#         plt.show()

#         # filtering
#         filtered=preprocessing(ppg_scaled,cut_l,cut_h,sr) # rppg는 0.75~2.0  cppg 0.1~0.3

        ppg_peaks,ppg_points=detect_peak(filtered,distance)# 4, peak detect , peak의 y,x 값 리턴
        time,ppg_peaks_x=Totimedomain(filtered,ppg_points,ppg_peaks) # 5. 타임도메인 전환(정규화데이터, 피크x, 피크y)
        
        ppg_hrv=cal_hrv(ppg_peaks,ppg_peaks_x) # 6. hrv계산
        ppg_frequency_features = get_frequency_domain_features(ppg_hrv)
        print("ppg_hrv_analysis:",ppg_frequency_features)
    
hrv_frequency(0,130)
# Out:
# ['cppg1.csv', 'cppg10.csv', 'cppg2.csv', 'cppg3.csv', 'cppg4.csv', 'cppg5.csv', 'cppg6.csv', 'cppg7.csv', 'cppg8.csv', 'cppg9.csv', 'cppg11.csv', 'cppg12.csv']
# file_name cppg1.csv
# <class 'numpy.ndarray'>
# hrv_shape: (546,)
# ppg_hrv_analysis: {'lf': 0.0005974828977833058, 'hf': 0.006234642268684341, 'lf_hf_ratio': 0.09583274741910558, 'lfnu': 8.74519835666619, 'hfnu': 91.2548016433338, 'total_power': 0.006890497054784582, 'vlf': 5.837188831693536e-05}
# file_name cppg10.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (405,)
# ppg_hrv_analysis: {'lf': 0.009459955494575581, 'hf': 0.030151739279011207, 'lf_hf_ratio': 0.313744935475769, 'lfnu': 23.881723689549155, 'hfnu': 76.11827631045084, 'total_power': 0.04213307400195583, 'vlf': 0.0025213792283690427}
# file_name cppg2.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (508,)
# ppg_hrv_analysis: {'lf': 0.0016327451049088905, 'hf': 0.004716225618721495, 'lf_hf_ratio': 0.3461974122755191, 'lfnu': 25.716689775114848, 'hfnu': 74.28331022488516, 'total_power': 0.006816598483093805, 'vlf': 0.0004676277594634187}
# file_name cppg3.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (388,)
# ppg_hrv_analysis: {'lf': 0.0015234903965708208, 'hf': 0.004041343851723001, 'lf_hf_ratio': 0.37697618724555954, 'lfnu': 27.377102867671628, 'hfnu': 72.62289713232836, 'total_power': 0.006045938977354122, 'vlf': 0.0004811047290602997}
# file_name cppg4.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (525,)
# ppg_hrv_analysis: {'lf': 0.00012551495293431698, 'hf': 0.0017704468222902068, 'lf_hf_ratio': 0.07089450603885063, 'lfnu': 6.620120435679841, 'hfnu': 93.37987956432016, 'total_power': 0.0019085390832985095, 'vlf': 1.2577308073985676e-05}
# file_name cppg5.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (423,)
# ppg_hrv_analysis: {'lf': 0.00295943582755668, 'hf': 0.010280643789615379, 'lf_hf_ratio': 0.28786483493826015, 'lfnu': 22.35209993539891, 'hfnu': 77.64790006460109, 'total_power': 0.01410363987764109, 'vlf': 0.0008635602604690311}
# file_name cppg6.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (436,)
# ppg_hrv_analysis: {'lf': 0.0019115393529775468, 'hf': 0.005320463876541123, 'lf_hf_ratio': 0.3592805810421655, 'lfnu': 26.43167172790063, 'hfnu': 73.56832827209936, 'total_power': 0.007832269255956741, 'vlf': 0.0006002660264380716}
# file_name cppg7.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (447,)
# ppg_hrv_analysis: {'lf': 0.0030560522553366456, 'hf': 0.011865816879525638, 'lf_hf_ratio': 0.25755093697845927, 'lfnu': 20.48035824276682, 'hfnu': 79.51964175723317, 'total_power': 0.01580375405178035, 'vlf': 0.0008818849169180678}
# file_name cppg8.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (441,)
# ppg_hrv_analysis: {'lf': 0.004396662626173121, 'hf': 0.006407693854722105, 'lf_hf_ratio': 0.6861536655552031, 'lfnu': 40.69342430479323, 'hfnu': 59.30657569520677, 'total_power': 0.012322140168716097, 'vlf': 0.001517783687820871}
# file_name cppg9.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (476,)
# ppg_hrv_analysis: {'lf': 0.009913715964802101, 'hf': 0.03101421812146843, 'lf_hf_ratio': 0.31965068169620253, 'lfnu': 24.222370823568404, 'hfnu': 75.77762917643159, 'total_power': 0.04391422560308901, 'vlf': 0.002986291516818483}
# file_name cppg11.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (519,)
# ppg_hrv_analysis: {'lf': 0.002073311882385715, 'hf': 0.01180791883531416, 'lf_hf_ratio': 0.17558656282299492, 'lfnu': 14.936081133944754, 'hfnu': 85.06391886605526, 'total_power': 0.014354203780201408, 'vlf': 0.0004729730625015334}
# file_name cppg12.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (450,)
# ppg_hrv_analysis: {'lf': 0.0001541042410923524, 'hf': 0.000638365171996404, 'lf_hf_ratio': 0.24140452495303188, 'lfnu': 19.446080636943492, 'hfnu': 80.55391936305651, 'total_power': 0.0008318802077122126, 'vlf': 3.941079462345622e-05}
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 22, using nperseg = 22
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %%
hrv_frequency(1,13)
# Out:
# ['rppg1.csv', 'rppg10.csv', 'rppg2.csv', 'rppg3.csv', 'rppg4.csv', 'rppg5.csv', 'rppg6.csv', 'rppg7.csv', 'rppg8.csv', 'rppg9.csv', 'rppg11.csv', 'rppg12.csv']
# file_name rppg1.csv
# <class 'numpy.ndarray'>
# hrv_shape: (541,)
# ppg_hrv_analysis: {'lf': 4.566797130455259e-05, 'hf': 0.00010434467250046396, 'lf_hf_ratio': 0.4376646187120817, 'lfnu': 30.442748121892254, 'hfnu': 69.55725187810773, 'total_power': 0.00016526386836039614, 'vlf': 1.5251224555379598e-05}
# file_name rppg10.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (398,)
# ppg_hrv_analysis: {'lf': 1.897107792911771e-06, 'hf': 5.116025032581854e-06, 'lf_hf_ratio': 0.37081675340325226, 'lfnu': 27.05078942773683, 'hfnu': 72.94921057226317, 'total_power': 7.631697347046643e-06, 'vlf': 6.185645215530185e-07}
# file_name rppg2.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (508,)
# ppg_hrv_analysis: {'lf': 0.0024241306940454253, 'hf': 0.005586942932157791, 'lf_hf_ratio': 0.43389215237771844, 'lfnu': 30.25974803322738, 'hfnu': 69.74025196677262, 'total_power': 0.008819709700816816, 'vlf': 0.0008086360746135995}
# file_name rppg3.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (383,)
# ppg_hrv_analysis: {'lf': 3.905745604209411e-06, 'hf': 1.3510868534580923e-05, 'lf_hf_ratio': 0.2890817562329688, 'lfnu': 22.425401246678152, 'hfnu': 77.57459875332185, 'total_power': 1.8632973903269052e-05, 'vlf': 1.2163597644787194e-06}
# file_name rppg4.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (524,)
# ppg_hrv_analysis: {'lf': 0.0001405233004882956, 'hf': 0.0003258812164811792, 'lf_hf_ratio': 0.43121018758198765, 'lfnu': 30.129060799274495, 'hfnu': 69.8709392007255, 'total_power': 0.0005132413188127629, 'vlf': 4.683680184328808e-05}
# file_name rppg5.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (423,)
# ppg_hrv_analysis: {'lf': 0.0001388607971618507, 'hf': 0.0003178375341986736, 'lf_hf_ratio': 0.4368923812347843, 'lfnu': 30.405365561152443, 'hfnu': 69.59463443884756, 'total_power': 0.0005030613684727138, 'vlf': 4.6363037112189525e-05}
# file_name rppg6.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (440,)
# ppg_hrv_analysis: {'lf': 0.0005610484679633496, 'hf': 0.0013008151580534057, 'lf_hf_ratio': 0.43130529690546193, 'lfnu': 30.133703678590507, 'hfnu': 69.8662963214095, 'total_power': 0.0020488681251489287, 'vlf': 0.0001870044991321734}
# file_name rppg7.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (447,)
# ppg_hrv_analysis: {'lf': 3.75936077667796e-06, 'hf': 2.3209055175028694e-05, 'lf_hf_ratio': 0.161978191198527, 'lfnu': 13.93986500137786, 'hfnu': 86.06013499862215, 'total_power': 2.7943411072795297e-05, 'vlf': 9.749951210886418e-07}
# file_name rppg8.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (440,)
# ppg_hrv_analysis: {'lf': 4.9866076984369265e-05, 'hf': 0.00013171916942316265, 'lf_hf_ratio': 0.37857873840799044, 'lfnu': 27.461524529616675, 'hfnu': 72.53847547038332, 'total_power': 0.00019789730667451672, 'vlf': 1.631206026698482e-05}
# file_name rppg9.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (476,)
# ppg_hrv_analysis: {'lf': 0.00010655348460592678, 'hf': 0.00024361621260717207, 'lf_hf_ratio': 0.43738256771006806, 'lfnu': 30.429099220736607, 'hfnu': 69.5709007792634, 'total_power': 0.00038575116758719167, 'vlf': 3.558147037409282e-05}
# file_name rppg11.csv
# <class 'numpy.ndarray'>
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '
# hrv_shape: (517,)
# ppg_hrv_analysis: {'lf': 0.0043078202946524174, 'hf': 0.009850550240005107, 'lf_hf_ratio': 0.4373177324813262, 'lfnu': 30.425960982639438, 'hfnu': 69.57403901736056, 'total_power': 0.015596855589983557, 'vlf': 0.0014384850553260315}
# file_name rppg12.csv
# <class 'numpy.ndarray'>
# hrv_shape: (449,)
# ppg_hrv_analysis: {'lf': 0.00010072546412960711, 'hf': 0.00023096782948934565, 'lf_hf_ratio': 0.4361017045200812, 'lfnu': 30.367048736692247, 'hfnu': 69.63295126330775, 'total_power': 0.0003653156330243273, 'vlf': 3.362233940537454e-05}
# C:\Users\user\anaconda3\envs\hrv\lib\site-packages\scipy\signal\spectral.py:1961: UserWarning: nperseg = 256 is greater than input length  = 3, using nperseg = 3
#   warnings.warn('nperseg = {0:d} is greater than input length '

# %% [markdown]
# # hrv feature

# %%
from hrvanalysis import get_frequency_domain_features
cppg_frequency_features = get_frequency_domain_features(cppg_hrv)
rppg_frequency_features = get_frequency_domain_features(rppg_hrv)

print("cppg:",cppg_frequency_features)
print("rppg:",rppg_frequency_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-70d0737357dd> in <module>
#       1 from hrvanalysis import get_frequency_domain_features
# ----> 2 cppg_frequency_features = get_frequency_domain_features(cppg_hrv)
#       3 rppg_frequency_features = get_frequency_domain_features(rppg_hrv)
#       4
#       5 print("cppg:",cppg_frequency_features)
#
# NameError: name 'cppg_hrv' is not defined

# %% [markdown]
# # csv로 기록

# %%
cppg_frequency_features['num']="1"
print(cppg_frequency_features.values())
f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\cppg.csv','w', newline='')
# fieldnames=cppg_frequency_features.keys()
# print(fieldnames)
wr = csv.writer(f)
wr.writerow(cppg_frequency_features.keys()) 
wr.writerow(cppg_frequency_features.values()) 
f.close()
# Out:
# dict_values([0.10822306266329913, 0.50597153800256, 0.21389160167098484, 17.62032140073726, 82.37967859926273, 0.6211251835636167, 0.006930582897757498, 'soeui'])

# %%
rppg_frequency_features['name']="soeui"
print(cppg_frequency_features.values())
f = open('D:\\prlab\\ysg\\HRV\\data\\hrv_feature\\rppg.csv','w', newline='')
# fieldnames=cppg_frequency_features.keys()
# print(fieldnames)
wr = csv.writer(f)
wr.writerow(rppg_frequency_features.keys()) 
wr.writerow(rppg_frequency_features.values()) 
f.close()
